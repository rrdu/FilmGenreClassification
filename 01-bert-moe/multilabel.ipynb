# %% [markdown]
# # SBERT Encoder w/ MLP MoE for Multilabel Film Genre Classification
#
# Short test poses a unique challenge for many NLP models due to limited context length while retaining the difficulties of the nuances of structured languages. This model aims to use several methods to address each of these concerns individually. First, a trained autoencoder, SBERT, will be used to create a new hidden representation for the short text input sequences. Then for the diverse classification tasks several expert models will be trained to selectively specialize in specific genre embeddings. Simple MLP models are sufficient for mapping the smaller embeddings to output classes while keeping the full model simple to train.

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

import torch
import torch.nn as nn
import torch.nn.functional as F

import lightning.pytorch as pl
from lightning.pytorch.callbacks import BaseFinetuning
from torchmetrics.classification import MultilabelF1Score
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Models

# %%
class Expert(nn.Module):
    """
    A simple Feed-Forward Network acting as a single 'Expert'.
    """
    def __init__(self, input_dim, hidden_dim, output_dim, dropout=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)

class TopKRouter(nn.Module):
    """
    Gating Network that selects the top-k experts for each input.
    """
    def __init__(self, input_dim, num_experts, top_k=2):
        super().__init__()
        self.gate = nn.Linear(input_dim, num_experts)
        self.top_k = top_k

    def forward(self, x):
        logits = self.gate(x)
        top_k_vals, top_k_indices = torch.topk(logits, self.top_k, dim=1)
        router_probs = F.softmax(top_k_vals, dim=1)
        return router_probs, top_k_indices, logits

class MoEClassifier(nn.Module):
    """
    The Mixture of Experts Classification Head.
    """
    def __init__(self, input_dim, num_classes, num_experts=4, top_k=2, expert_hidden_dim=128):
        super().__init__()
        self.num_experts = num_experts
        self.top_k = top_k
        
        self.router = TopKRouter(input_dim, num_experts, top_k=top_k)
        self.experts = nn.ModuleList([
            Expert(input_dim, expert_hidden_dim, num_classes) 
            for _ in range(num_experts)
        ])

    def forward(self, x):
        batch_size = x.size(0)
        router_probs, expert_indices, router_logits = self.router(x)
        
        final_output = torch.zeros(batch_size, self.experts[0].net[-1].out_features).to(x.device)
        
        for k in range(self.top_k):
            selected_experts = expert_indices[:, k]
            gate_weight = router_probs[:, k].unsqueeze(1)
            
            for expert_idx in range(self.num_experts):
                mask = (selected_experts == expert_idx)
                if mask.any():
                    expert_input = x[mask]
                    expert_output = self.experts[expert_idx](expert_input)
                    final_output[mask] += gate_weight[mask] * expert_output
                    
        return final_output, router_logits

class SBERT_MoE_Model(nn.Module):
    """
    Full End-to-End Model: SBERT Encoder + MoE Classifier
    """
    def __init__(self, model_name='all-MiniLM-L6-v2', num_classes=5, num_experts=8, top_k=2):
        super().__init__()
        # 1. Initialize SBERT
        self.sbert = SentenceTransformer(model_name)
        
        # 2. Capture device choice
        target_device = self.sbert.device 
        
        # 3. Initialize MoE head
        embedding_dim = self.sbert.get_sentence_embedding_dimension()
        self.moe_head = MoEClassifier(
            input_dim=embedding_dim,
            num_classes=num_classes,
            num_experts=num_experts,
            top_k=top_k
        )
        
        # 4. Force MoE head to same device
        self.moe_head.to(target_device)

    def forward(self, text_input):
        # Encode and Detach to treat embeddings as fixed features initially
        features = self.sbert.encode(text_input, convert_to_tensor=True)
        
        # Important: Clone and detach to avoid "Inference Tensor" errors during backprop
        # If unfreezing later, the optimizer handles the graph connection, 
        # but for the initial forward pass logic, this is safe.
        features = features.clone().detach() 
        
        logits, router_logits = self.moe_head(features)
        return logits, router_logits

# %% [markdown]
# ## Training

# %%
class MoE_LightningModule(pl.LightningModule):
    def __init__(self, model, num_classes, num_experts, learning_rate=1e-3, aux_loss_weight=0.1):
        super().__init__()
        self.save_hyperparameters(ignore=['model'])
        
        # Organize modules
        self.backbone = model.sbert
        self.head = model.moe_head
        self.learning_rate = learning_rate
        self.num_experts = num_experts
        self.aux_loss_weight = aux_loss_weight
        
        # Multi-Label Loss & Metrics
        self.criterion = nn.BCEWithLogitsLoss()
        self.val_f1 = MultilabelF1Score(num_labels=num_classes, threshold=0.5, average='micro')

    def forward(self, x):
        # 1. Tokenize the raw text
        # This converts ["Hello world"] into {'input_ids': ..., 'attention_mask': ...}
        features = self.backbone.tokenize(x)
        
        # 2. Move inputs to the correct device (GPU/MPS)
        # LightningModule provides self.device
        features = {key: value.to(self.device) for key, value in features.items()}
        
        # 3. Pass through SBERT backbone
        # calling .forward() or __call__() allows gradients to flow (unlike .encode())
        out = self.backbone(features)
        
        # 4. Extract the sentence embedding
        embeddings = out['sentence_embedding']
        
        # 5. Pass through MoE Head
        return self.head(embeddings)

    def _compute_load_balancing_loss(self, router_logits):
        probs = F.softmax(router_logits, dim=1)
        mean_probs = probs.mean(dim=0)
        aux_loss = (mean_probs ** 2).sum() * self.num_experts
        return aux_loss

    def training_step(self, batch, batch_idx):
        texts, targets = batch
        logits, router_logits = self(texts)
        
        cls_loss = self.criterion(logits, targets)
        aux_loss = self._compute_load_balancing_loss(router_logits)
        
        total_loss = cls_loss + (self.aux_loss_weight * aux_loss)
        
        self.log("train_loss", total_loss)
        return total_loss

    def validation_step(self, batch, batch_idx):
        texts, targets = batch
        
        # Forward pass (we don't need router logits for validation metrics)
        logits, _ = self(texts)
        
        # Calculate Loss
        val_loss = self.criterion(logits, targets)
        
        # Update F1 Score
        self.val_f1(logits, targets)
        
        # Log metrics so the Scheduler can find 'val_loss'
        self.log("val_loss", val_loss, prog_bar=True)
        self.log("val_f1", self.val_f1, prog_bar=True)

    # def configure_optimizers(self):
    #     # Filter ensures we don't crash trying to optimize frozen params
    #     return torch.optim.AdamW(filter(lambda p: p.requires_grad, self.parameters()), lr=self.learning_rate)
    
    def configure_optimizers(self):
        # 1. Initialize Optimizer with ONLY the Head (Backbone added later by Callback)
        optimizer = torch.optim.AdamW(
            self.head.parameters(), 
            lr=1e-3, 
            weight_decay=0.01
        )
        
        # 2. Use ReduceLROnPlateau (Safe for dynamic unfreezing)
        # It waits for 'val_loss' to stop improving, then lowers LR
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=0.1,
            patience=2
        )
        
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "monitor": "val_loss", # Required for ReduceLROnPlateau
                "interval": "epoch",
                "frequency": 1
            }
        }
        
class ProductionFinetuning(BaseFinetuning):
    def __init__(self, unfreeze_at_epoch=2, backbone_lr=2e-5):
        super().__init__()
        self._unfreeze_at_epoch = unfreeze_at_epoch
        self._backbone_lr = backbone_lr

    def freeze_before_training(self, pl_module):
        # Start with SBERT frozen
        self.freeze(pl_module.backbone)

    def finetune_function(self, pl_module, current_epoch, optimizer):
        # When we hit the target epoch...
        if current_epoch == self._unfreeze_at_epoch:
            print(f"\n❄️ -> 🔥 Unfreezing SBERT Backbone at Epoch {current_epoch}")
            
            # Unfreeze AND add to the optimizer with the Low LR
            self.unfreeze_and_add_param_group(
                modules=pl_module.backbone,
                optimizer=optimizer,
                lr=self._backbone_lr 
            )

# %% [markdown]
# ## Data

# %%
from torch.utils.data import Dataset


class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels 
    
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

def map_logits_to_labels(logits, class_names, threshold=0.5):
    probs = torch.sigmoid(logits).cpu()
    predictions_mask = (probs > threshold).numpy()
    batch_results = []
    for is_active in predictions_mask:
        active_labels = [class_names[idx] for idx, val in enumerate(is_active) if val]
        batch_results.append(active_labels)
    return batch_results, probs

# %% [markdown]
# ## Demo

# %%
from torch.utils.data import DataLoader


CLASS_NAMES = ["Finance", "Sports", "Tech", "Urgent"]

texts = [
    "Inflation data released this morning caused immediate volatility across global markets. The S&P 500 dropped 2% within minutes of the opening bell as traders reacted to the Federal Reserve's signaling of potentially higher interest rates for the remainder of Q4.",
    "The new smart-jersey utilizes embedded bio-sensors to track player fatigue in real-time during the match. Coaches can now monitor heart rate variability and sprint speed directly from the sidelines, allowing for data-driven substitution decisions in the fourth quarter.",
    "After months of negotiation, the star quarterback has agreed to a record-breaking 50 million dollar extension. This deal makes him the highest-paid player in league history and significantly impacts the team's salary cap for the upcoming trading season.",
    "Benchmark tests for the new M3 processor show a 15% drop in multi-core performance compared to the previous generation. Thermal throttling appears to be the primary bottleneck, as the chip reaches 90 degrees Celsius under sustained heavy workloads like video rendering.",
    "CRITICAL ALERT: Primary database cluster US-East-1 is currently unresponsive due to a cascading failure in the load balancer. Response times have spiked to 5000ms. Immediate engineering intervention is required to prevent a total service outage for enterprise customers.",
    "Emergency board meeting required: The Q3 projections show a cash flow deficit that will impact payroll by next Friday. We need to approve the emergency line of credit immediately to ensure operations continue without interruption.",
]

# Multi-hot labels (Float Tensors)
labels = torch.tensor([
    [1.0, 0.0, 0.0, 0.0], # Finance
    [0.0, 1.0, 1.0, 0.0], # Tech + Sports
    [1.0, 1.0, 0.0, 0.0], # Finance + Sports
    [0.0, 0.0, 1.0, 0.0], # Tech
    [0.0, 0.0, 1.0, 1.0], # Tech + Urgent
    [1.0, 0.0, 0.0, 1.0], # Finance + Urgent
])

dataset = TextDataset(texts, labels)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# --- Initialize Models ---
num_classes = len(CLASS_NAMES)
backbone = SBERT_MoE_Model(num_classes=num_classes, num_experts=4, top_k=2)

# Wrap in Lightning
pl_module = MoE_LightningModule(
    model=backbone, 
    num_classes=num_classes, 
    num_experts=4,
    aux_loss_weight=0.1
)

# Callback to unfreeze SBERT after 1 epoch
finetune_cb = ProductionFinetuning(unfreeze_at_epoch=3, backbone_lr=2e-5)

# --- Train ---
print("--- Starting Training ---")
trainer = pl.Trainer(
    max_epochs=10,
    accelerator="auto",
    callbacks=[finetune_cb],
    enable_progress_bar=True,
    log_every_n_steps=1 
)

# trainer.fit(pl_module, dataloader, dataloader)
trainer.fit(
    pl_module, 
    train_dataloaders=dataloader, 
    val_dataloaders=dataloader # Using same data for demo purposes
)

# --- Inference ---
print("\n--- Running Inference ---")
pl_module.eval()

test_texts = [
    "The tech company bought a sports team.", 
    "Urgent: The bank is collapsing."
]

with torch.no_grad():
    # Run forward pass
    logits, _ = pl_module(test_texts)
    
    # Map outputs
    predicted_labels, probs = map_logits_to_labels(logits, CLASS_NAMES, threshold=0.5)
    
    for text, lbls, raw_probs in zip(test_texts, predicted_labels, probs):
        print(f"\nInput: {text}")
        print(f"Predicted Labels: {lbls}")
        print(f"Raw Probabilities: {[round(p, 2) for p in raw_probs.tolist()]}")
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# /home/dodogama/anaconda3/envs/nlp-py310/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# You are using a CUDA device ('NVIDIA GeForce RTX 3060 Ti') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type                | Params | Mode
# ----------------------------------------------------------
# 0 | backbone  | SentenceTransformer | 22.7 M | train
# 1 | head      | MoEClassifier       | 200 K  | train
# 2 | criterion | BCEWithLogitsLoss   | 0      | train
# 3 | val_f1    | MultilabelF1Score   | 0      | train
# ----------------------------------------------------------
# 200 K     Trainable params
# 22.7 M    Non-trainable params
# 22.9 M    Total params
# 91.656    Total estimated model params size (MB)
# 34        Modules in train mode
# 120       Modules in eval mode
# --- Starting Training ---
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/dodogama/anaconda3/envs/nlp-py310/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:484: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /home/dodogama/anaconda3/envs/nlp-py310/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:433: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/dodogama/anaconda3/envs/nlp-py310/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:433: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/dodogama/anaconda3/envs/nlp-py310/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:527: Found 120 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ❄️ -> 🔥 Unfreezing SBERT Backbone at Epoch 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# --- Running Inference ---
#
# Input: The tech company bought a sports team.
# Predicted Labels: ['Sports', 'Tech']
# Raw Probabilities: [0.5, 0.5, 0.5, 0.44]
#
# Input: Urgent: The bank is collapsing.
# Predicted Labels: ['Urgent']
# Raw Probabilities: [0.5, 0.43, 0.5, 0.52]

# %% [markdown]
# ## Movie Genre Execution

# %%
import torch
import pandas as pd
from pathlib import Path
from torch.utils.data import DataLoader, Dataset


class IMDBDataset(Dataset):
    def __init__(self, data_dir_path, filename, class_names, text_col='description', label_col='genre_list'):
        """
        Args:
            data_dir_path (Path or str): Relative path to data directory.
            filename (str): The CSV filename (e.g., 'train.csv').
            class_names (list): List of valid classes (ORDER MATTERS).
            text_col (str): Column name for text.
            label_col (str): Column name for labels.
        """
        # 1. Setup Path safely
        self.data_path = Path(data_dir_path) / filename
        
        if not self.data_path.exists():
            raise FileNotFoundError(f"File not found at: {self.data_path.resolve()}")
            
        print(f"Loading data from {self.data_path.name}...")
        self.df = pd.read_csv(self.data_path)
        
        # 2. Process Text (Handle NaNs, ensure strings)
        self.texts = self.df[text_col].fillna("").astype(str).tolist()
        
        # 3. Process Labels (Multi-hot Encoding)
        # Create map: "Action" -> 0, "Drama" -> 1, etc.
        self.class_to_idx = {cls: i for i, cls in enumerate(class_names)}
        self.num_classes = len(class_names)
        self.labels = []
        
        # Track unseen genres for safety warning
        unseen_genres = set()
        
        for genre_str in self.df[label_col]:
            # Initialize zero vector [0.0, 0.0, ...]
            label_vec = torch.zeros(self.num_classes, dtype=torch.float)
            
            if pd.notna(genre_str):
                # Split "Action, Drama" -> ["Action", "Drama"]
                # .strip() removes whitespace around words
                current_genres = [g.strip() for g in str(genre_str).split(',')]
                
                for genre in current_genres:
                    if genre in self.class_to_idx:
                        idx = self.class_to_idx[genre]
                        label_vec[idx] = 1.0
                    else:
                        # Track genres that don't match our class list
                        unseen_genres.add(genre)
            
            self.labels.append(label_vec)

        # 4. Warning System
        # If this is the test set, and it has weird genres not in train, warn the user.
        if unseen_genres:
            print(f"⚠️  WARNING in {filename}: Found {len(unseen_genres)} genres not in the provided class list.")
            print(f"   Examples of ignored genres: {list(unseen_genres)[:5]}")
            print(f"   (These were ignored during label creation)")

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

    @staticmethod
    def discover_classes(data_dir_path, filename, label_col='genre_list'):
        """
        Static utility to scan a CSV and return sorted unique class names.
        Use this ONCE on your TRAINING set only.
        """
        path = Path(data_dir_path) / filename
        if not path.exists():
             raise FileNotFoundError(f"File not found at: {path.resolve()}")

        df = pd.read_csv(path)
        
        # Split by comma, explode list to rows, strip whitespace, find unique
        genres = df[label_col].dropna().astype(str).str.split(',').explode().str.strip().unique()
        
        return sorted(list(genres))


DATA_DIR = Path('../data/imdb_arh_trimmed')
CLASS_NAMES = IMDBDataset.discover_classes(DATA_DIR, 'imdb_arh_train.csv')
NUM_WORKERS = 4

tr_ds = IMDBDataset(data_dir_path=DATA_DIR, filename='imdb_arh_train.csv', class_names=CLASS_NAMES)
va_ds = IMDBDataset(data_dir_path=DATA_DIR, filename='imdb_arh_val.csv', class_names=CLASS_NAMES)
te_ds = IMDBDataset(data_dir_path=DATA_DIR, filename='imdb_arh_test.csv', class_names=CLASS_NAMES)

tr_loader = DataLoader(tr_ds, batch_size=32, num_workers=NUM_WORKERS, shuffle=True)
va_loader = DataLoader(va_ds, batch_size=64, num_workers=NUM_WORKERS, shuffle=False)
te_loader = DataLoader(te_ds, batch_size=64, num_workers=NUM_WORKERS, shuffle=False)

print("--- Sanity Checks ---")
# 1. Check if classes were discovered
print(f"Num classes: {len(CLASS_NAMES)}")
print(f"First 5 classes: {CLASS_NAMES[:5]}")

# 2. Check Dataset lengths
print(f"Train size: {len(tr_ds)}")
print(f"Val size:   {len(va_ds)}")

# 3. Inspect a single sample
sample_text, sample_label = tr_ds[0]

print(f"\nSample Text Type: {type(sample_text)}") # Should be <class 'str'>
print(f"Sample Label Type: {type(sample_label)}") # Should be <class 'torch.Tensor'>
print(f"Sample Label Shape: {sample_label.shape}") # Should be torch.Size([num_classes])
print(f"Sample Label Dtype: {sample_label.dtype}") # Should be torch.float32

print("\n--- DataLoader Batch Check ---")

# Get one batch from the training loader
batch_texts, batch_labels = next(iter(tr_loader))

print(f"Batch Text Length: {len(batch_texts)}") # Should match batch_size (32)
print(f"Batch Label Shape: {batch_labels.shape}") # Should be [32, num_classes]

# Check if shuffling works (Compare first item of two different iterator calls)
batch_texts_2, _ = next(iter(tr_loader))
if batch_texts[0] != batch_texts_2[0]:
    print("Shuffle is working (First elements differ).")
else:
    print("Warning: Shuffle might not be working or dataset is very small.")
# Out:
# Loading data from imdb_arh_train.csv...
# Loading data from imdb_arh_val.csv...
# Loading data from imdb_arh_test.csv...
# --- Sanity Checks ---
# Num classes: 26
# First 5 classes: ['Action', 'Adult', 'Adventure', 'Animation', 'Biography']
# Train size: 67772
# Val size:   14523
#
# Sample Text Type: <class 'str'>
# Sample Label Type: <class 'torch.Tensor'>
# Sample Label Shape: torch.Size([26])
# Sample Label Dtype: torch.float32
#
# --- DataLoader Batch Check ---
# Batch Text Length: 32
# Batch Label Shape: torch.Size([32, 26])
# Shuffle is working (First elements differ).

# %%
# 1. Import WandB components
from lightning.pytorch.loggers import WandbLogger
from lightning.pytorch.callbacks import ModelCheckpoint, EarlyStopping
from dotenv import load_dotenv
import wandb

load_dotenv()
wandb.login(key=os.getenv("WANDB_API_KEY"))

# 2. Initialize the Logger
wandb_logger = WandbLogger(
    project="MovieGenreMultilabelMoE", 
    name="testrun",
    log_model=False,
)

# --- Initialize Models ---
num_classes = len(CLASS_NAMES)
backbone = SBERT_MoE_Model(num_classes=num_classes, num_experts=4, top_k=2)

# Wrap in Lightning
pl_module = MoE_LightningModule(
    model=backbone, 
    num_classes=num_classes, 
    num_experts=10,
    aux_loss_weight=0.1
)

# Callback to stop training early
early_stop_cb = EarlyStopping(
    monitor="val_loss",  # Watch the validation loss
    min_delta=0.00,      # Minimum change to qualify as an improvement
    patience=3,          # Stop if no improvement for 3 epochs in a row
    verbose=True,
    mode="min"
)

# Callback to save best model based on validation loss
checkpoint_cb = ModelCheckpoint(
    dirpath="checkpoints/",
    filename="moe-film-{epoch:02d}-{val_loss:.2f}",
    monitor="val_loss",
    mode="min",
    save_top_k=1,
    save_last=True
)

# Callback to unfreeze SBERT after k epochs
finetune_cb = ProductionFinetuning(unfreeze_at_epoch=5, backbone_lr=2e-5)

# --- Train ---
print("--- Starting Training ---")
trainer = pl.Trainer(
    max_epochs=20,
    accelerator="auto",
    callbacks=[finetune_cb, early_stop_cb, checkpoint_cb],
    enable_progress_bar=True,
    log_every_n_steps=1,
    logger=wandb_logger  # <--- 3. CONNECT LOGGER HERE
)

# Optional: Log your class names for reference in the dashboard
wandb_logger.experiment.config.update({"class_names": CLASS_NAMES})

trainer.fit(
    pl_module, 
    train_dataloaders=tr_loader, 
    val_dataloaders=va_loader,
)

# 4. Close the run (Important for Notebooks)
wandb.finish()
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/dodogama/.netrc
# wandb: Currently logged in as: conradli90 (conradli90-duke-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# --- Starting Training ---
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>./wandb/run-20251121_212442-905jp9jn</code>
# Syncing run <strong><a href='https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE/runs/905jp9jn' target="_blank">testrun</a></strong> to <a href='https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE' target="_blank">https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE</a>
#  View run at <a href='https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE/runs/905jp9jn' target="_blank">https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE/runs/905jp9jn</a>
# /home/dodogama/anaconda3/envs/nlp-py310/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:751: Checkpoint directory /home/dodogama/code/FilmGenreClassification/01-bert-moe/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type                | Params | Mode
# ----------------------------------------------------------
# 0 | backbone  | SentenceTransformer | 22.7 M | train
# 1 | head      | MoEClassifier       | 212 K  | train
# 2 | criterion | BCEWithLogitsLoss   | 0      | train
# 3 | val_f1    | MultilabelF1Score   | 0      | train
# ----------------------------------------------------------
# 212 K     Trainable params
# 22.7 M    Non-trainable params
# 22.9 M    Total params
# 91.701    Total estimated model params size (MB)
# 34        Modules in train mode
# 120       Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/dodogama/anaconda3/envs/nlp-py310/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:527: Found 120 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved. New best score: 0.148
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0.0. New best score: 0.146
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.145
# ❄️ -> 🔥 Unfreezing SBERT Backbone at Epoch 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.009 >= min_delta = 0.0. New best score: 0.136
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Monitored metric val_loss did not improve in the last 3 records. Best score: 0.136. Signaling Trainer to stop.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇███████</td></tr><tr><td>train_loss</td><td>█▄▅▅▆██▆▅▅▆▅▄▇▅▄▅▆▅▄▆▄▅▆▄▃▂▂▃▃▁▃▃▃▂▃▂▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>val_f1</td><td>▁▂▃▇███</td></tr><tr><td>val_loss</td><td>▇▆▆▁▁▃█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>6</td></tr><tr><td>train_loss</td><td>0.35004</td></tr><tr><td>trainer/global_step</td><td>14825</td></tr><tr><td>val_f1</td><td>0.6173</td></tr><tr><td>val_loss</td><td>0.14916</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">testrun</strong> at: <a href='https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE/runs/905jp9jn' target="_blank">https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE/runs/905jp9jn</a><br> View project at: <a href='https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE' target="_blank">https://wandb.ai/conradli90-duke-university/MovieGenreMultilabelMoE</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251121_212442-905jp9jn/logs</code>

# %% [markdown]
# ### Inference

# %%
import torch
from torchmetrics import MetricCollection
from torchmetrics.classification import (
    MultilabelF1Score,
    MultilabelPrecision,
    MultilabelRecall,
    MultilabelAccuracy
)
# ==========================================
# 1. SETUP & LOADING
# ==========================================

# A. Define the path to your best checkpoint
# (Replace this string with the actual path printed during training)
CHECKPOINT_PATH = "checkpoints/moe-film-epoch=04-val_loss=0.14.ckpt"

# B. Re-initialize the Skeleton Architecture
# These arguments MUST match what you used during training
num_classes = len(CLASS_NAMES)
backbone_skeleton = SBERT_MoE_Model(num_classes=num_classes, num_experts=4, top_k=2)

# C. Load the Weights
print(f"Loading model from: {CHECKPOINT_PATH}")
loaded_model = MoE_LightningModule.load_from_checkpoint(
    CHECKPOINT_PATH,
    model=backbone_skeleton,
    num_classes=num_classes,
    num_experts=4
)

# D. Prepare for Inference
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loaded_model.to(device)
loaded_model.eval()

# ==========================================
# 2. INITIALIZE GLOBAL METRICS
# ==========================================
# We use a MetricCollection to track F1, Precision, and Recall efficiently
metrics = MetricCollection({
    'accuracy': MultilabelAccuracy(num_labels=num_classes, threshold=0.5, average='micro'),
    'f1': MultilabelF1Score(num_labels=num_classes, threshold=0.5, average='micro'),
    'precision': MultilabelPrecision(num_labels=num_classes, threshold=0.5, average='micro'),
    'recall': MultilabelRecall(num_labels=num_classes, threshold=0.5, average='micro')
}).to(device)

# ==========================================
# 3. INFERENCE LOOP (VISUAL + ACCUMULATION)
# ==========================================
print("\n--- Running Inference on Full Test Loader ---")

with torch.no_grad():
    for batch_idx, batch in enumerate(te_loader):
        
        # Unpack
        texts, true_label_tensors = batch
        
        # Move labels to device for metric calculation
        true_label_tensors = true_label_tensors.to(device)
        
        # Forward Pass
        logits, _ = loaded_model(texts)
        
        # --- A. ACCUMULATE GLOBAL METRICS ---
        # This updates the running counters for the whole dataset
        metrics.update(logits, true_label_tensors)

        # --- B. VISUALIZE (Your Snippet) ---
        # Only print details for the first 5 batches
        if batch_idx < 5: 
            # Map outputs to class names for display
            predicted_labels_batch, probs_batch = map_logits_to_labels(logits, CLASS_NAMES, threshold=0.5)
            
            for i, (text, pred_lbls, probs) in enumerate(zip(texts, predicted_labels_batch, probs_batch)):
                
                # Decode Ground Truth
                # (Note: true_label_tensors is now on GPU, so we move to cpu for logic)
                cpu_labels = true_label_tensors[i].cpu()
                true_indices = (cpu_labels == 1.0).nonzero(as_tuple=False).squeeze()
                
                if true_indices.ndim == 0 and true_indices.numel() == 1:
                    true_indices = [true_indices.item()]
                elif true_indices.ndim > 0:
                    true_indices = true_indices.tolist()
                else: 
                    true_indices = []
                    
                actual_lbls = [CLASS_NAMES[idx] for idx in true_indices]

                # Print Output
                print(f"\n[Batch {batch_idx} - Sample {i}]")
                print(f"Input Text:    {text[:80]}...") 
                print(f"PREDICTED:     {pred_lbls}")
                print(f"GROUND TRUTH:  {actual_lbls}")
                
                significant_probs = {CLASS_NAMES[j]: round(p, 3) for j, p in enumerate(probs.tolist()) if p > 0.1}
                print(f"High Probs:    {significant_probs}")

# ==========================================
# 4. CALCULATE & DISPLAY FINAL RESULTS
# ==========================================
print("\n" + "="*30)
print("FINAL EVALUATION REPORT")
print("="*30)

# Compute metrics over all batches processed
final_results = metrics.compute()

# Print nicely
for metric_name, value in final_results.items():
    print(f"Global {metric_name.capitalize()}: {value.item():.4f}")

# Reset metrics for future use
metrics.reset()
# Out:
# Loading model from: checkpoints/moe-film-epoch=04-val_loss=0.14.ckpt
#
# --- Running Inference on Full Test Loader ---
#
# [Batch 0 - Sample 0]
# Input Text:    A story about an Indian girl who was captured by Azzizal. Her family tries to do...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Action': 0.488, 'Adventure': 0.129, 'Drama': 0.671, 'Romance': 0.502}
#
# [Batch 0 - Sample 1]
# Input Text:    It's Friday night--she's moving in with her boyfriend tomorrow--so she goes out,...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.729, 'Drama': 0.332, 'Romance': 0.948}
#
# [Batch 0 - Sample 2]
# Input Text:    A Malaysian return comes to Madurai to find out the murderer of his father and u...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama']
# High Probs:    {'Action': 0.973, 'Crime': 0.272, 'Drama': 0.484, 'Thriller': 0.246}
#
# [Batch 0 - Sample 3]
# Input Text:    At his agent's party, Ryan, a young screenwriter, and Joel, Ryan's boyfriend, me...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.36, 'Drama': 0.309, 'Horror': 0.795, 'Mystery': 0.114, 'Romance': 0.162, 'Thriller': 0.429}
#
# [Batch 0 - Sample 4]
# Input Text:    Welcome to the dark underworld of Hollywood's Golden Age where monsters really d...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Thriller']
# High Probs:    {'Action': 0.32, 'Horror': 0.837, 'Thriller': 0.165}
#
# [Batch 0 - Sample 5]
# Input Text:    A goon tries to win his wife back by making a movie on their love story....
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Action', 'Comedy', 'Drama']
# High Probs:    {'Comedy': 0.791, 'Drama': 0.127, 'Romance': 0.985}
#
# [Batch 0 - Sample 6]
# Input Text:    Party girl meets a male ballet dancer on the Internet....
# PREDICTED:     ['Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.405, 'Drama': 0.427, 'Music': 0.122, 'Musical': 0.138, 'Romance': 0.995}
#
# [Batch 0 - Sample 7]
# Input Text:    A college student Tanya jokingly agrees to engage in virtual sex with a stranger...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance', 'Thriller']
# High Probs:    {'Comedy': 0.502, 'Drama': 0.302, 'Horror': 0.235, 'Romance': 0.811}
#
# [Batch 0 - Sample 8]
# Input Text:    A newlywed couple visits the husband's hometown in Geneva, where they are subjec...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Horror', 'Mystery']
# High Probs:    {'Action': 0.101, 'Comedy': 0.166, 'Crime': 0.104, 'Drama': 0.711, 'Horror': 0.234, 'Mystery': 0.112, 'Romance': 0.606, 'Thriller': 0.317}
#
# [Batch 0 - Sample 9]
# Input Text:    Sherry awakes trapped in a medical facility. Enlisting the help of Clovis, the n...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.188, 'Horror': 0.964, 'Mystery': 0.371, 'Thriller': 0.344}
#
# [Batch 0 - Sample 10]
# Input Text:    Forced to travel with her boyfriend, Laine begins to experience premonitions ass...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Mystery', 'Thriller']
# High Probs:    {'Drama': 0.166, 'Horror': 0.988, 'Mystery': 0.262, 'Thriller': 0.217}
#
# [Batch 0 - Sample 11]
# Input Text:    When a Caribbean family vacation takes a disastrous turn, a father finds himself...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Adventure', 'Crime']
# High Probs:    {'Action': 0.853, 'Adventure': 0.326, 'Drama': 0.515, 'Romance': 0.129, 'Thriller': 0.168}
#
# [Batch 0 - Sample 12]
# Input Text:    Young Vishnu and his younger brother live with their hardworking dad, a farmer, ...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Crime', 'Drama']
# High Probs:    {'Action': 0.925, 'Crime': 0.168, 'Drama': 0.623, 'Thriller': 0.151}
#
# [Batch 0 - Sample 13]
# Input Text:    A small group of survivors must fight their way through a now vampire infested w...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Comedy': 0.127, 'Horror': 0.962, 'Sci-Fi': 0.186}
#
# [Batch 0 - Sample 14]
# Input Text:    In the small American town of Orton Creek, David Farmer is accidentally killed b...
# PREDICTED:     []
# GROUND TRUTH:  ['Action', 'Drama', 'Thriller']
# High Probs:    {'Action': 0.296, 'Adventure': 0.121, 'Comedy': 0.192, 'Drama': 0.471, 'Horror': 0.169, 'Music': 0.153, 'Romance': 0.405, 'Western': 0.265}
#
# [Batch 0 - Sample 15]
# Input Text:    Individual dreams and responsibilities cause problems for two lovers....
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.377, 'Drama': 0.688, 'Romance': 0.991}
#
# [Batch 0 - Sample 16]
# Input Text:    In the near future, a television corporation has developed the software to creat...
# PREDICTED:     ['Action', 'Sci-Fi']
# GROUND TRUTH:  ['Action', 'Sci-Fi', 'Thriller']
# High Probs:    {'Action': 0.811, 'Adventure': 0.233, 'Comedy': 0.268, 'Drama': 0.175, 'Fantasy': 0.104, 'Romance': 0.118, 'Sci-Fi': 0.713}
#
# [Batch 0 - Sample 17]
# Input Text:    The Yorozuya gang returns to protect the country's shogun when the Shinsengumi p...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Adventure', 'Comedy']
# High Probs:    {'Action': 0.997, 'Adventure': 0.117, 'Crime': 0.242, 'Drama': 0.299}
#
# [Batch 0 - Sample 18]
# Input Text:    Jake Russo is a very likable hired killer for the mob that is trapped between tw...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Crime', 'Thriller']
# High Probs:    {'Action': 0.981, 'Crime': 0.323, 'Drama': 0.469, 'Thriller': 0.149}
#
# [Batch 0 - Sample 19]
# Input Text:    Princess Thamarai is ordered out of the palace by her brother for marrying a Naa...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Action', 'Drama', 'Thriller']
# High Probs:    {'Comedy': 0.628, 'Drama': 0.465, 'Musical': 0.112, 'Romance': 0.928}
#
# [Batch 0 - Sample 20]
# Input Text:    A group of surfers discover an old board game which claims a life every time it ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Horror', 'Thriller']
# High Probs:    {'Action': 0.522, 'Adventure': 0.303, 'Comedy': 0.247, 'Drama': 0.198, 'Horror': 0.394, 'Romance': 0.105, 'Sci-Fi': 0.213, 'Thriller': 0.109}
#
# [Batch 0 - Sample 21]
# Input Text:    A rookie thief receives on-the-job training from a crew of bungling burglars....
# PREDICTED:     ['Action', 'Comedy']
# GROUND TRUTH:  ['Action', 'Comedy', 'Crime']
# High Probs:    {'Action': 0.837, 'Adventure': 0.109, 'Comedy': 0.737, 'Crime': 0.368, 'Drama': 0.217, 'Romance': 0.107}
#
# [Batch 0 - Sample 22]
# Input Text:    An obvious pink film knock-off of the "JOSHÛU SASORI" series. with much more emp...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Action', 'Crime']
# High Probs:    {'Action': 0.477, 'Comedy': 0.559, 'Drama': 0.195, 'Romance': 0.503}
#
# [Batch 0 - Sample 23]
# Input Text:    THE TRUE LIFE STORY OF RAMPADOR ALINDOG, A SADISTIC TORTURE AND MURDER THE RECIP...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.86, 'Biography': 0.107, 'Crime': 0.408, 'Drama': 0.472, 'Thriller': 0.209}
#
# [Batch 0 - Sample 24]
# Input Text:    Honor, Pride and Sacrifice of team Special Force,...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Adventure', 'Thriller']
# High Probs:    {'Action': 0.995, 'Adventure': 0.172}
#
# [Batch 0 - Sample 25]
# Input Text:    A would-be playwright and a young woman escaping from a job at a gas station mee...
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.525, 'Drama': 0.589, 'Romance': 0.998}
#
# [Batch 0 - Sample 26]
# Input Text:    Beom-wi, a first-rate student of swordsmanship, realizes that he will never be t...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.918, 'Adventure': 0.216, 'Comedy': 0.221, 'Drama': 0.456}
#
# [Batch 0 - Sample 27]
# Input Text:    A romantic comedy in which a shy florist teams up with a movie star to push her ...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.924, 'Drama': 0.125, 'Romance': 0.997}
#
# [Batch 0 - Sample 28]
# Input Text:    A fisherman's daughter is secretly in love with a strong man who works for her f...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Adventure', 'Drama', 'Romance']
# High Probs:    {'Action': 0.237, 'Adventure': 0.171, 'Drama': 0.636, 'Romance': 0.595, 'Thriller': 0.137}
#
# [Batch 0 - Sample 29]
# Input Text:    When a martial arts expert discovers the existence of an illegal slave trade in ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Crime']
# High Probs:    {'Action': 0.998, 'Adventure': 0.195, 'Drama': 0.275}
#
# [Batch 0 - Sample 30]
# Input Text:    After High School, a modern-day Peter Pan and his Millennial sidekick discover p...
# PREDICTED:     ['Comedy']
# GROUND TRUTH:  ['Adventure', 'Comedy', 'Romance']
# High Probs:    {'Action': 0.419, 'Adventure': 0.116, 'Comedy': 0.731, 'Drama': 0.215, 'Horror': 0.105, 'Romance': 0.443, 'Sci-Fi': 0.22}
#
# [Batch 0 - Sample 31]
# Input Text:    The passion and romance, that lends itself to the most cherished, precious, and ...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Comedy': 0.187, 'Drama': 0.599, 'Romance': 0.954}
#
# [Batch 0 - Sample 32]
# Input Text:    Biopic of female Japanese murderer Takahashi Oden....
# PREDICTED:     []
# GROUND TRUTH:  ['Crime', 'Drama', 'Romance']
# High Probs:    {'Action': 0.475, 'Crime': 0.329, 'Drama': 0.452, 'Horror': 0.272, 'Mystery': 0.193, 'Romance': 0.114, 'Thriller': 0.238}
#
# [Batch 0 - Sample 33]
# Input Text:    Márcia is a married woman with a son. She finds that her husband has an affair. ...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Action': 0.174, 'Drama': 0.734, 'Romance': 0.877}
#
# [Batch 0 - Sample 34]
# Input Text:    Colton returns home to simplify his life, and hopefully reunite with the girl of...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.149, 'Comedy': 0.77, 'Drama': 0.3, 'Horror': 0.141, 'Romance': 0.641}
#
# [Batch 0 - Sample 35]
# Input Text:    Winona, a successful artist looking to get away from her stressful life. Her man...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.257, 'Drama': 0.388, 'Horror': 0.833, 'Mystery': 0.108, 'Romance': 0.365, 'Thriller': 0.117}
#
# [Batch 0 - Sample 36]
# Input Text:    Junior-high students are restrained by their teachers and parents... One day, th...
# PREDICTED:     ['Drama']
# GROUND TRUTH:  ['Action', 'Comedy', 'Drama']
# High Probs:    {'Action': 0.321, 'Comedy': 0.349, 'Drama': 0.721, 'Romance': 0.492}
#
# [Batch 0 - Sample 37]
# Input Text:    In a post-apocalyptic American Frontier, a soldier fends off a brutal warmonger ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Sci-Fi']
# High Probs:    {'Action': 0.916, 'Adventure': 0.263, 'Drama': 0.218, 'Sci-Fi': 0.346, 'Thriller': 0.149}
#
# [Batch 0 - Sample 38]
# Input Text:    When an online romance turns serious, Scout and Steven rush to the altar. They m...
# PREDICTED:     ['Romance']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.276, 'Drama': 0.365, 'Horror': 0.291, 'Romance': 0.722, 'Thriller': 0.224}
#
# [Batch 0 - Sample 39]
# Input Text:    Fraternity brothers at Alpine College recruit Ronnie Duke to seduce Susan Benchl...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Music', 'Romance']
# High Probs:    {'Comedy': 0.699, 'Drama': 0.428, 'Music': 0.108, 'Romance': 0.976}
#
# [Batch 0 - Sample 40]
# Input Text:    A monk renounces his role to become King after his brother is killed. His new Qu...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Biography', 'History']
# High Probs:    {'Action': 0.942, 'Adventure': 0.307, 'Drama': 0.611, 'History': 0.14}
#
# [Batch 0 - Sample 41]
# Input Text:    A regular guy going through difficult times stages a bank heist....
# PREDICTED:     ['Action', 'Crime']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.928, 'Comedy': 0.123, 'Crime': 0.645, 'Drama': 0.443, 'Thriller': 0.173}
#
# [Batch 0 - Sample 42]
# Input Text:    A film director whose life crumbles after the suicide of his Hollywood starlet g...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Romance', 'Sci-Fi']
# High Probs:    {'Comedy': 0.336, 'Drama': 0.307, 'Fantasy': 0.137, 'Horror': 0.618, 'Romance': 0.329, 'Sci-Fi': 0.306, 'Thriller': 0.208}
#
# [Batch 0 - Sample 43]
# Input Text:    For generations, a family lives in fear of a dark and terrible curse....
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.288, 'Horror': 0.987, 'Mystery': 0.15, 'Thriller': 0.246}
#
# [Batch 0 - Sample 44]
# Input Text:    An accidental meeting helps to learn a lot of new in surrounding world and his s...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Comedy': 0.358, 'Drama': 0.532, 'Romance': 0.903}
#
# [Batch 0 - Sample 45]
# Input Text:    After his release from prison, Taro, a small-time drug runner, doesn't waste tim...
# PREDICTED:     ['Action', 'Crime']
# GROUND TRUTH:  ['Action', 'Crime']
# High Probs:    {'Action': 0.966, 'Comedy': 0.1, 'Crime': 0.629, 'Drama': 0.343, 'Thriller': 0.139}
#
# [Batch 0 - Sample 46]
# Input Text:    After being dumped by his girlfriend, Bass is set up on a series of blind dates ...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.852, 'Drama': 0.231, 'Romance': 0.985}
#
# [Batch 0 - Sample 47]
# Input Text:    The plot is unknown at this time....
# PREDICTED:     []
# GROUND TRUTH:  ['Action', 'Adventure', 'Family']
# High Probs:    {'Action': 0.34, 'Adventure': 0.19, 'Comedy': 0.153, 'Drama': 0.21, 'Fantasy': 0.154, 'Horror': 0.352, 'Romance': 0.335, 'Thriller': 0.124}
#
# [Batch 0 - Sample 48]
# Input Text:    To support her paralytic father, Chato works as a utility girl for a burlesque s...
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.521, 'Drama': 0.516, 'Musical': 0.175, 'Romance': 0.967}
#
# [Batch 0 - Sample 49]
# Input Text:    Jiang Jie is a senior captain of the Flying Tigers, a special police force; for ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.994, 'Crime': 0.185, 'Drama': 0.216, 'Thriller': 0.101}
#
# [Batch 0 - Sample 50]
# Input Text:    A young woman's corrupted spirit haunts the new residents of the apartment she c...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Thriller']
# High Probs:    {'Drama': 0.39, 'Horror': 0.958, 'Mystery': 0.142, 'Romance': 0.136, 'Thriller': 0.194}
#
# [Batch 0 - Sample 51]
# Input Text:    Tanjiro finds his family slaughtered and the lone survivor, his sister Nezuko Ka...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Action', 'Animation', 'Fantasy']
# High Probs:    {'Action': 0.138, 'Drama': 0.444, 'Horror': 0.77, 'Mystery': 0.103, 'Thriller': 0.23}
#
# [Batch 0 - Sample 52]
# Input Text:    Spartacus who is about to die in The Coliseum prays to his Gods to curse Julius ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Action': 0.853, 'Adventure': 0.449, 'Comedy': 0.14, 'Fantasy': 0.23, 'Horror': 0.233, 'Sci-Fi': 0.123}
#
# [Batch 0 - Sample 53]
# Input Text:    Caridad 'Ariadna' is an attractive young singer with ambition that seeks success...
# PREDICTED:     ['Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.213, 'Drama': 0.491, 'Musical': 0.208, 'Romance': 0.96}
#
# [Batch 0 - Sample 54]
# Input Text:    Rumours arise in the Frontier government when Sheryl Nome arrives to the fleet f...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Animation', 'Sci-Fi']
# High Probs:    {'Action': 0.979, 'Adventure': 0.439, 'Drama': 0.234}
#
# [Batch 0 - Sample 55]
# Input Text:    A Japanese Jiu-Jitsu master settles in Brazil and teaches young Carlos Gracie th...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Biography', 'Drama']
# High Probs:    {'Action': 0.995, 'Adventure': 0.1, 'Comedy': 0.108, 'Drama': 0.41}
#
# [Batch 0 - Sample 56]
# Input Text:    A musician loves a married woman who becomes a nun and dies. Later he loves her ...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Drama': 0.861, 'Romance': 0.989}
#
# [Batch 0 - Sample 57]
# Input Text:    A group of teens in a small North Carolina town come face-to-face with an evil t...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.106, 'Drama': 0.124, 'Horror': 0.983, 'Thriller': 0.218}
#
# [Batch 0 - Sample 58]
# Input Text:    In the early days of the Republic, in Jiang Nan, two brothers help their uncle C...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama']
# High Probs:    {'Action': 0.985, 'Adventure': 0.165, 'Crime': 0.27, 'Drama': 0.395}
#
# [Batch 0 - Sample 59]
# Input Text:    Depicts bizarre phenomena on the set of a drama that reenacts ghost stories, pre...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.372, 'Fantasy': 0.14, 'Horror': 0.906, 'Mystery': 0.259, 'Thriller': 0.225}
#
# [Batch 0 - Sample 60]
# Input Text:    Un ranchero mexicano envia a su hijo para la Guardia Forestal Mexicana tal como ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Adventure', 'Comedy']
# High Probs:    {'Action': 0.839, 'Comedy': 0.103, 'Crime': 0.129, 'Drama': 0.396, 'Western': 0.105}
#
# [Batch 0 - Sample 61]
# Input Text:    The story follows three different girls with unique personalities in a span of 1...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.502, 'Drama': 0.405, 'Romance': 0.931}
#
# [Batch 0 - Sample 62]
# Input Text:    Inspired by the real story of the conflict between the student from four differe...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Crime', 'Drama']
# High Probs:    {'Action': 0.831, 'Crime': 0.272, 'Drama': 0.598, 'Thriller': 0.224}
#
# [Batch 0 - Sample 63]
# Input Text:    Follows the legends of the Holy Grail and how it came to Britain in the first ce...
# PREDICTED:     ['Action', 'Adventure']
# GROUND TRUTH:  ['Action', 'Adventure', 'History']
# High Probs:    {'Action': 0.913, 'Adventure': 0.666, 'Drama': 0.381, 'Fantasy': 0.188, 'History': 0.328}
#
# [Batch 1 - Sample 0]
# Input Text:    The film focuses on a young man who struggles to stand on his own feet. Thrilled...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Action', 'Comedy', 'Drama']
# High Probs:    {'Action': 0.14, 'Comedy': 0.121, 'Drama': 0.709, 'Romance': 0.848}
#
# [Batch 1 - Sample 1]
# Input Text:    An ugly duckling having undergone a remarkable change, still harbors feelings fo...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.836, 'Drama': 0.434, 'Romance': 0.995}
#
# [Batch 1 - Sample 2]
# Input Text:    While out for a walk in the countryside, Marina and Juvenal stop to take some pi...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.153, 'Drama': 0.255, 'Horror': 0.959, 'Mystery': 0.161, 'Thriller': 0.122}
#
# [Batch 1 - Sample 3]
# Input Text:    The protagonist of the film is a young man named Kuba. Whom due to his seriously...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.944, 'Comedy': 0.168, 'Crime': 0.308, 'Drama': 0.468}
#
# [Batch 1 - Sample 4]
# Input Text:    Stash involves an idealistic woman raising money for her church. She embarks on ...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.202, 'Drama': 0.157, 'Horror': 0.905, 'Mystery': 0.101, 'Thriller': 0.149}
#
# [Batch 1 - Sample 5]
# Input Text:    The more a family seems perfect, the more secrets it is hiding....
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.294, 'Horror': 0.829, 'Mystery': 0.16, 'Thriller': 0.257}
#
# [Batch 1 - Sample 6]
# Input Text:    An adventure film set in Germany after the Nazis have surrendered in World War I...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'War']
# High Probs:    {'Action': 0.977, 'Adventure': 0.493, 'Comedy': 0.128, 'Drama': 0.165, 'War': 0.135}
#
# [Batch 1 - Sample 7]
# Input Text:    Two men fall in love but struggle to be in a relationship openly in society....
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.107, 'Drama': 0.788, 'Romance': 0.979}
#
# [Batch 1 - Sample 8]
# Input Text:    A young woman after her first date with her boyfriend begins to feel movements i...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.148, 'Drama': 0.349, 'Horror': 0.925, 'Mystery': 0.195, 'Romance': 0.24, 'Thriller': 0.203}
#
# [Batch 1 - Sample 9]
# Input Text:    Tan, a Northern Chinese kung fu expert, kills a man using his lethal bootwork in...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Comedy', 'Drama']
# High Probs:    {'Action': 0.995, 'Adventure': 0.122, 'Comedy': 0.108, 'Drama': 0.339}
#
# [Batch 1 - Sample 10]
# Input Text:    Sagar reveals that it revolves around six to seven characters."Ashwin plays a me...
# PREDICTED:     ['Romance']
# GROUND TRUTH:  ['Action', 'Thriller']
# High Probs:    {'Comedy': 0.363, 'Drama': 0.42, 'Romance': 0.96}
#
# [Batch 1 - Sample 11]
# Input Text:    Wages of Cine presents an anthology of twelve tales that transverse space and ti...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Drama', 'Fantasy', 'Horror']
# High Probs:    {'Action': 0.141, 'Adventure': 0.109, 'Comedy': 0.148, 'Drama': 0.266, 'Fantasy': 0.411, 'Horror': 0.763, 'Mystery': 0.173, 'Sci-Fi': 0.112}
#
# [Batch 1 - Sample 12]
# Input Text:    The late Master Yu, villain in Jet Li's Shaolin Temple series and the Top swords...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama', 'History']
# High Probs:    {'Action': 0.999, 'Adventure': 0.359, 'Drama': 0.345, 'History': 0.1}
#
# [Batch 1 - Sample 13]
# Input Text:    Five friends decide to spend their midsummer night at an old summer place in the...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.128, 'Horror': 0.988, 'Thriller': 0.126}
#
# [Batch 1 - Sample 14]
# Input Text:    In the studio of a radio house, a housewife, a juvenile psychologist, a head stu...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Action': 0.382, 'Comedy': 0.276, 'Crime': 0.349, 'Drama': 0.593, 'Romance': 0.586, 'Thriller': 0.151}
#
# [Batch 1 - Sample 15]
# Input Text:    Alice works for "Rebelle" magazine, where she needs to let her hair down to get ...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.773, 'Drama': 0.34, 'Romance': 0.979}
#
# [Batch 1 - Sample 16]
# Input Text:    Pran Piyo is Ajay Singh love story of Ajay and Preeti. Ajay saves Preeti's life ...
# PREDICTED:     ['Action', 'Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Action': 0.547, 'Drama': 0.563, 'Romance': 0.665}
#
# [Batch 1 - Sample 17]
# Input Text:    Talks about the Hindu-Muslim politics and conflicts in Kerala which connects wit...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Drama', 'Thriller']
# High Probs:    {'Action': 0.985, 'Drama': 0.577, 'Thriller': 0.125}
#
# [Batch 1 - Sample 18]
# Input Text:    Are visions rooted in reality?...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Action': 0.134, 'Drama': 0.379, 'Fantasy': 0.322, 'Horror': 0.824, 'Mystery': 0.215, 'Thriller': 0.255}
#
# [Batch 1 - Sample 19]
# Input Text:    Two engineers arrive in an isolated mountain village to install a cellular radio...
# PREDICTED:     ['Drama']
# GROUND TRUTH:  ['Drama', 'Horror', 'Thriller']
# High Probs:    {'Action': 0.475, 'Drama': 0.504, 'Horror': 0.363, 'Mystery': 0.164, 'Sci-Fi': 0.117, 'Thriller': 0.287}
#
# [Batch 1 - Sample 20]
# Input Text:    Luna Ng (Kelly Chen) is a columnist who gave her first boyfriend a vinyl record ...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.58, 'Drama': 0.249, 'Music': 0.189, 'Musical': 0.152, 'Romance': 0.944}
#
# [Batch 1 - Sample 21]
# Input Text:    Sammo plays a Tai Chi master who must teach his son (Timmy Hung Tin Ming) how to...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama']
# High Probs:    {'Action': 0.991, 'Comedy': 0.408, 'Drama': 0.457}
#
# [Batch 1 - Sample 22]
# Input Text:    A young couple accept an offer for $2 million to stay in a haunted house for a w...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.107, 'Horror': 0.994, 'Mystery': 0.135, 'Thriller': 0.241}
#
# [Batch 1 - Sample 23]
# Input Text:    An Australian trading company called Chandlerdale Exports hires a drunk Korean t...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Comedy']
# High Probs:    {'Action': 0.827, 'Adventure': 0.233, 'Comedy': 0.208, 'Crime': 0.251, 'Drama': 0.243, 'Thriller': 0.209}
#
# [Batch 1 - Sample 24]
# Input Text:    LOVE explores the relationship between friends, family, and lovers. This story b...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.154, 'Drama': 0.729, 'Romance': 0.989}
#
# [Batch 1 - Sample 25]
# Input Text:    Nikhil Kapoor decides to re-locate from Parksville, USA to Bombay; meets with An...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance', 'Thriller']
# High Probs:    {'Action': 0.139, 'Comedy': 0.199, 'Drama': 0.552, 'Romance': 0.799}
#
# [Batch 1 - Sample 26]
# Input Text:    During the last days of the Second World War a last generation german submarine,...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'History', 'War']
# High Probs:    {'Action': 0.676, 'Adventure': 0.236, 'Drama': 0.313, 'Horror': 0.284, 'Sci-Fi': 0.121, 'Thriller': 0.112, 'War': 0.142}
#
# [Batch 1 - Sample 27]
# Input Text:    A University journalism graduate and aspiring human rights activist, Melissa, is...
# PREDICTED:     ['Drama']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Action': 0.368, 'Comedy': 0.179, 'Crime': 0.197, 'Drama': 0.625, 'Romance': 0.479, 'Thriller': 0.197}
#
# [Batch 1 - Sample 28]
# Input Text:    A swordsman is looking for his parents' enemy and finally meets the old swordsma...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Adventure']
# High Probs:    {'Action': 0.975, 'Adventure': 0.197, 'Drama': 0.526}
#
# [Batch 1 - Sample 29]
# Input Text:    A collection of 62 over-the-top horror movie prevues from the golden Grindhouse ...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.146, 'Horror': 0.993}
#
# [Batch 1 - Sample 30]
# Input Text:    Tells the tale of a group of ex eco-crusaders who find themselves being systemat...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Comedy', 'Horror']
# High Probs:    {'Action': 0.639, 'Adventure': 0.12, 'Drama': 0.194, 'Horror': 0.452, 'Thriller': 0.149}
#
# [Batch 1 - Sample 31]
# Input Text:    This movie serves as a spin off that's based on the much-loved TV drama series "...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Family', 'Romance']
# High Probs:    {'Action': 0.183, 'Comedy': 0.129, 'Drama': 0.662, 'Romance': 0.818}
#
# [Batch 1 - Sample 32]
# Input Text:    To escape the horrors of urban life, a young family moves to the country only to...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Action': 0.107, 'Drama': 0.258, 'Horror': 0.87, 'Sci-Fi': 0.217, 'Thriller': 0.194}
#
# [Batch 1 - Sample 33]
# Input Text:    A boy falls in love with his crush but things take a turn for the worse when she...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.198, 'Drama': 0.616, 'Horror': 0.236, 'Romance': 0.74, 'Thriller': 0.12}
#
# [Batch 1 - Sample 34]
# Input Text:    Rakesh and Sumesh are two plain-clothes agents in the city's Criminal Investigat...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Comedy', 'Crime']
# High Probs:    {'Action': 0.878, 'Adventure': 0.13, 'Comedy': 0.242, 'Crime': 0.425, 'Drama': 0.198, 'Thriller': 0.174}
#
# [Batch 1 - Sample 35]
# Input Text:    Shooting a film on location in Oswiecim makes a young writer see the emptiness o...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.117, 'Drama': 0.658, 'Horror': 0.439, 'Romance': 0.635}
#
# [Batch 1 - Sample 36]
# Input Text:    A young girl with a special gift comes of age during one of the most desolate pe...
# PREDICTED:     ['Fantasy']
# GROUND TRUTH:  ['Drama', 'Fantasy', 'Horror']
# High Probs:    {'Action': 0.11, 'Adventure': 0.13, 'Drama': 0.39, 'Fantasy': 0.565, 'Horror': 0.357, 'Romance': 0.265}
#
# [Batch 1 - Sample 37]
# Input Text:    The young Chef Ah Sheng struggles to grow as a professional chef in an industry ...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Comedy': 0.277, 'Drama': 0.674, 'Romance': 0.949}
#
# [Batch 1 - Sample 38]
# Input Text:    An erotic comedy set entirely in the New York City Subway System, shot without p...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Action': 0.145, 'Comedy': 0.92, 'Drama': 0.206, 'Romance': 0.782}
#
# [Batch 1 - Sample 39]
# Input Text:    When four terrorists infiltrate India, ACP Jai and Ranvir set out to track them ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.997, 'Adventure': 0.105, 'Crime': 0.141, 'Drama': 0.215, 'Thriller': 0.316}
#
# [Batch 1 - Sample 40]
# Input Text:    A city cop is sent out to the country to go undercover and bust up a ring of moo...
# PREDICTED:     ['Action', 'Crime']
# GROUND TRUTH:  ['Action', 'Comedy']
# High Probs:    {'Action': 0.958, 'Comedy': 0.486, 'Crime': 0.537, 'Drama': 0.273}
#
# [Batch 1 - Sample 41]
# Input Text:    A man leads a secret life as an underworld crime boss. Since the death of his wi...
# PREDICTED:     ['Action', 'Crime']
# GROUND TRUTH:  ['Action', 'Crime']
# High Probs:    {'Action': 0.971, 'Crime': 0.551, 'Drama': 0.489, 'Thriller': 0.341}
#
# [Batch 1 - Sample 42]
# Input Text:    The is a story about a disabled teenage boy, Russell Wilson, who is bitten by a ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.567, 'Adventure': 0.142, 'Comedy': 0.103, 'Drama': 0.468, 'Horror': 0.206, 'Romance': 0.157}
#
# [Batch 1 - Sample 43]
# Input Text:    Hairi works at Klon Technologies searching new vaccines for new diseases. He's t...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Action', 'Comedy', 'Sci-Fi']
# High Probs:    {'Comedy': 0.55, 'Drama': 0.49, 'Horror': 0.148, 'Romance': 0.774}
#
# [Batch 1 - Sample 44]
# Input Text:    The story of a policeman who decides to become a murderer aiming that the media ...
# PREDICTED:     ['Action', 'Crime', 'Drama']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.765, 'Crime': 0.547, 'Drama': 0.547, 'Mystery': 0.123, 'Romance': 0.157, 'Thriller': 0.291}
#
# [Batch 1 - Sample 45]
# Input Text:    Zarrar is a secret agent gone rogue. He is on a mission to end corruption, aimin...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama', 'Thriller']
# High Probs:    {'Action': 0.997, 'Adventure': 0.108, 'Crime': 0.148, 'Drama': 0.147, 'Thriller': 0.322}
#
# [Batch 1 - Sample 46]
# Input Text:    A feature anthology of short tales of sexual intimacy set in four American citie...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.365, 'Drama': 0.642, 'Romance': 0.922}
#
# [Batch 1 - Sample 47]
# Input Text:    A troubled family traveling cross country are highjacked by a desperate man. Onl...
# PREDICTED:     ['Action', 'Thriller']
# GROUND TRUTH:  ['Horror', 'Sci-Fi']
# High Probs:    {'Action': 0.909, 'Crime': 0.139, 'Drama': 0.278, 'Thriller': 0.521}
#
# [Batch 1 - Sample 48]
# Input Text:    Estranged brothers reunite to find their missing father in an old mining town bu...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Action': 0.141, 'Comedy': 0.114, 'Drama': 0.166, 'Fantasy': 0.119, 'Horror': 0.829, 'Thriller': 0.152}
#
# [Batch 1 - Sample 49]
# Input Text:    A group of high school friends reunite after two years when one of their fathers...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Fantasy', 'Horror', 'Mystery']
# High Probs:    {'Drama': 0.318, 'Horror': 0.927, 'Mystery': 0.148, 'Thriller': 0.195}
#
# [Batch 1 - Sample 50]
# Input Text:    The story revolves around three friends who are desperately looking out for suit...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Action', 'Drama']
# High Probs:    {'Comedy': 0.584, 'Drama': 0.446, 'Romance': 0.976}
#
# [Batch 1 - Sample 51]
# Input Text:    The fifth installment in the "Les Boys" franchise goes back to the winter of 196...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Action': 0.621, 'Adventure': 0.212, 'Animation': 0.244, 'Comedy': 0.408, 'Drama': 0.297, 'Romance': 0.382}
#
# [Batch 1 - Sample 52]
# Input Text:    The first Bangladeshi horror movie....
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Drama', 'Horror']
# High Probs:    {'Drama': 0.111, 'Horror': 0.969, 'Mystery': 0.132, 'Thriller': 0.154}
#
# [Batch 1 - Sample 53]
# Input Text:    Swedish agent Hamilton tracks 200 stolen grenades to Russians at the Uzbek/Afgha...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama', 'Thriller']
# High Probs:    {'Action': 0.987, 'Adventure': 0.132, 'Crime': 0.236, 'Drama': 0.293, 'Thriller': 0.259}
#
# [Batch 1 - Sample 54]
# Input Text:    Inmates from the local insane asylum escape and terrorize the small town of Pine...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.183, 'Horror': 0.978, 'Mystery': 0.104, 'Thriller': 0.314}
#
# [Batch 1 - Sample 55]
# Input Text:    Former Green Beret, Frank Huttle, kills the daughter of a terrorist mastermind t...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.998, 'Adventure': 0.177, 'Crime': 0.121, 'Drama': 0.175, 'Thriller': 0.284}
#
# [Batch 1 - Sample 56]
# Input Text:    Five high school seniors (3 cute girls) in a VW van on their way to camp by a ri...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Thriller']
# High Probs:    {'Drama': 0.153, 'Horror': 0.977, 'Mystery': 0.119, 'Thriller': 0.255}
#
# [Batch 1 - Sample 57]
# Input Text:    Since her childhood, Jessica has been haunted by recurrent nightmares whose mean...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Fantasy', 'Horror', 'Mystery']
# High Probs:    {'Drama': 0.291, 'Fantasy': 0.115, 'Horror': 0.967, 'Mystery': 0.236, 'Thriller': 0.348}
#
# [Batch 1 - Sample 58]
# Input Text:    Three sisters come to Hollywood to be movie stars. Complications arise when two ...
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.532, 'Drama': 0.557, 'Musical': 0.162, 'Romance': 0.942}
#
# [Batch 1 - Sample 59]
# Input Text:    There's an outsider in every school and Rose is one of those people. Everyone la...
# PREDICTED:     ['Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Action': 0.135, 'Comedy': 0.407, 'Drama': 0.467, 'Romance': 0.849}
#
# [Batch 1 - Sample 60]
# Input Text:    An author tells the story of how, as a young boy growing up in a 1960s small tow...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Fantasy', 'Horror', 'Mystery']
# High Probs:    {'Drama': 0.357, 'Horror': 0.967, 'Mystery': 0.278, 'Thriller': 0.206}
#
# [Batch 1 - Sample 61]
# Input Text:    How Far Will You Go For Love ?...
# PREDICTED:     ['Romance']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Comedy': 0.227, 'Drama': 0.44, 'Romance': 0.904}
#
# [Batch 1 - Sample 62]
# Input Text:    A group of modern day Pittsburgh teenagers spend their Thanksgiving break experi...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.453, 'Drama': 0.622, 'Romance': 0.917}
#
# [Batch 1 - Sample 63]
# Input Text:    Damak, a village guy moved to the city after some of his football teammates blam...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Action': 0.501, 'Comedy': 0.205, 'Drama': 0.578, 'Romance': 0.491}
#
# [Batch 2 - Sample 0]
# Input Text:    In Paris, the story of three women on the verge of mental collapse and suicide....
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.151, 'Drama': 0.852, 'Romance': 0.916}
#
# [Batch 2 - Sample 1]
# Input Text:    A survivor of an attack on a rebel group opposing the Manchu invasion of China c...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama']
# High Probs:    {'Action': 0.988, 'Adventure': 0.182, 'Drama': 0.428, 'History': 0.118, 'War': 0.146}
#
# [Batch 2 - Sample 2]
# Input Text:    After meeting an ex-lover Eva runs away from her marriage and family into a worl...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.193, 'Drama': 0.819, 'Romance': 0.952}
#
# [Batch 2 - Sample 3]
# Input Text:    An undercover agent infiltrates a crime ring run by a charismatic boss....
# PREDICTED:     ['Action', 'Crime']
# GROUND TRUTH:  ['Action', 'Crime', 'Drama']
# High Probs:    {'Action': 0.977, 'Crime': 0.617, 'Drama': 0.445, 'Thriller': 0.242}
#
# [Batch 2 - Sample 4]
# Input Text:    Story of a bus driver who had to deal with unexpected, pitiful events caused mai...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Action': 0.588, 'Comedy': 0.258, 'Crime': 0.123, 'Drama': 0.654, 'Romance': 0.355}
#
# [Batch 2 - Sample 5]
# Input Text:    A father waits in the emergency room; a clock ticks in the background; the sound...
# PREDICTED:     ['Drama', 'Horror']
# GROUND TRUTH:  ['Action', 'Drama']
# High Probs:    {'Action': 0.134, 'Comedy': 0.263, 'Drama': 0.508, 'Horror': 0.511, 'Mystery': 0.159, 'Romance': 0.335, 'Thriller': 0.235}
#
# [Batch 2 - Sample 6]
# Input Text:    Woman inherits a traveling circus which brings financial difficulties....
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.541, 'Drama': 0.629, 'Musical': 0.123, 'Romance': 0.884}
#
# [Batch 2 - Sample 7]
# Input Text:    Michael Myers is loose in Haddonfield again for one last night. Can Maxwell Loom...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.268, 'Horror': 0.991}
#
# [Batch 2 - Sample 8]
# Input Text:    A millionaire, who drove his wife to commit suicide, starts believing that he is...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Thriller']
# High Probs:    {'Drama': 0.308, 'Horror': 0.954, 'Mystery': 0.288, 'Thriller': 0.281}
#
# [Batch 2 - Sample 9]
# Input Text:    Rebecca is searching for her sister, a young journalist who went missing while i...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Mystery', 'Thriller']
# High Probs:    {'Drama': 0.292, 'Horror': 0.907, 'Mystery': 0.369, 'Thriller': 0.415}
#
# [Batch 2 - Sample 10]
# Input Text:    Is there a monster on the loose on the streets of Los Angeles, or is it just a k...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Action': 0.851, 'Crime': 0.351, 'Drama': 0.243, 'Horror': 0.175, 'Thriller': 0.258}
#
# [Batch 2 - Sample 11]
# Input Text:    A lifelong womanizer gets a taste of his own medicine....
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.542, 'Drama': 0.567, 'Romance': 0.876}
#
# [Batch 2 - Sample 12]
# Input Text:    The two principal characters have a love affair, with highs and lows accompanied...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Musical', 'Romance']
# High Probs:    {'Comedy': 0.226, 'Drama': 0.624, 'Music': 0.207, 'Musical': 0.114, 'Romance': 0.989}
#
# [Batch 2 - Sample 13]
# Input Text:    Three women vacation together at a popular travel destination for college co-eds...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.713, 'Drama': 0.176, 'Horror': 0.144, 'Romance': 0.753}
#
# [Batch 2 - Sample 14]
# Input Text:    A story full of ghosts and scares about the theme of cursed figures and the prin...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.244, 'Fantasy': 0.201, 'Horror': 0.972, 'Mystery': 0.116, 'Thriller': 0.122}
#
# [Batch 2 - Sample 15]
# Input Text:    When a young car thief stumbles on the invention of the century (and the various...
# PREDICTED:     ['Action', 'Comedy']
# GROUND TRUTH:  ['Action', 'Sci-Fi']
# High Probs:    {'Action': 0.876, 'Adventure': 0.429, 'Comedy': 0.652, 'Drama': 0.128, 'Romance': 0.261}
#
# [Batch 2 - Sample 16]
# Input Text:    Gordon Comstock quits his job at an advertising agency in order to write poetry,...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.808, 'Drama': 0.397, 'Music': 0.15, 'Musical': 0.149, 'Romance': 0.985}
#
# [Batch 2 - Sample 17]
# Input Text:    Avasian Parish, Louisiana is a small and tight-knit community, still reeling fro...
# PREDICTED:     ['Drama']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Action': 0.125, 'Comedy': 0.168, 'Drama': 0.608, 'Horror': 0.45, 'Romance': 0.35, 'Thriller': 0.118}
#
# [Batch 2 - Sample 18]
# Input Text:    A boy meets girl love story, set in New York City. Only problem is, she's with h...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.635, 'Drama': 0.301, 'Romance': 0.998}
#
# [Batch 2 - Sample 19]
# Input Text:    A police officer fights with the scum of the society....
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Crime', 'Drama']
# High Probs:    {'Action': 0.993, 'Crime': 0.41, 'Drama': 0.45, 'Thriller': 0.191}
#
# [Batch 2 - Sample 20]
# Input Text:    Maggie (Renie Riano) continues her forever-ever efforts to crash Manhattan's top...
# PREDICTED:     ['Crime', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Music', 'Romance']
# High Probs:    {'Action': 0.494, 'Comedy': 0.453, 'Crime': 0.527, 'Drama': 0.474, 'Romance': 0.525}
#
# [Batch 2 - Sample 21]
# Input Text:    Disturbed homemaker, Alice, finds herself trapped in her home amidst a zombie ou...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Drama', 'Horror', 'Thriller']
# High Probs:    {'Comedy': 0.328, 'Drama': 0.108, 'Horror': 0.955}
#
# [Batch 2 - Sample 22]
# Input Text:    A New York attorney is sent to Shanghai on business, where he finds himself in a...
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.565, 'Drama': 0.54, 'Romance': 0.981}
#
# [Batch 2 - Sample 23]
# Input Text:    A tragic love story set against the turbulent backdrop of the 1920's Chicago jaz...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Action', 'Crime', 'Drama']
# High Probs:    {'Drama': 0.846, 'Musical': 0.123, 'Romance': 0.961}
#
# [Batch 2 - Sample 24]
# Input Text:    Thandi finds out the complexities of love, when David, the schoolboy Mister Char...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.74, 'Drama': 0.446, 'Romance': 0.985}
#
# [Batch 2 - Sample 25]
# Input Text:    An illiterate rural girl changes herself into a modern and urban one to get the ...
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.638, 'Drama': 0.553, 'Romance': 0.985}
#
# [Batch 2 - Sample 26]
# Input Text:    A true story about a Flemish resistance warrior....
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Drama', 'History', 'Romance']
# High Probs:    {'Action': 0.954, 'Adventure': 0.192, 'Biography': 0.242, 'Drama': 0.464, 'History': 0.175}
#
# [Batch 2 - Sample 27]
# Input Text:    Six friends meet every evening in a basement to make music. During the daytime, ...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.431, 'Drama': 0.611, 'Horror': 0.237, 'Romance': 0.793}
#
# [Batch 2 - Sample 28]
# Input Text:    A pretty African immigrant in the UK falls in love with a recently divorced busi...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.364, 'Drama': 0.723, 'Romance': 0.993}
#
# [Batch 2 - Sample 29]
# Input Text:    We follow Victoria as she matures from a spoiled privileged young girl to a woma...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.118, 'Drama': 0.802, 'Romance': 0.912}
#
# [Batch 2 - Sample 30]
# Input Text:    Lester and his boys like to have themselves "a good ole' time" by kidnapping and...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Comedy', 'Horror']
# High Probs:    {'Action': 0.167, 'Drama': 0.198, 'Horror': 0.838, 'Thriller': 0.226}
#
# [Batch 2 - Sample 31]
# Input Text:    When Anna, a boutique food publisher, recognises that her niece Nina has an eati...
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.653, 'Drama': 0.709, 'Romance': 0.996}
#
# [Batch 2 - Sample 32]
# Input Text:    "Tu Y Yo" tells a fictional story that takes place during an imaginary tour of D...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Adventure', 'Music', 'Romance']
# High Probs:    {'Adventure': 0.118, 'Comedy': 0.295, 'Drama': 0.501, 'Fantasy': 0.138, 'Horror': 0.152, 'Mystery': 0.127, 'Romance': 0.731, 'Thriller': 0.124}
#
# [Batch 2 - Sample 33]
# Input Text:    Dracula kills another innocent victim and Dr. Seward decides it's time to wipe h...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.152, 'Fantasy': 0.194, 'Horror': 0.97}
#
# [Batch 2 - Sample 34]
# Input Text:    A rotoscope-animated modern-day Cinderella story set in the underbelly of New Yo...
# PREDICTED:     []
# GROUND TRUTH:  ['Animation', 'Fantasy', 'Romance']
# High Probs:    {'Action': 0.47, 'Adventure': 0.262, 'Animation': 0.407, 'Comedy': 0.251, 'Drama': 0.213, 'Fantasy': 0.344, 'Romance': 0.48}
#
# [Batch 2 - Sample 35]
# Input Text:    Tang River Baths is a tragic love story that takes place during the turbulent ti...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Drama': 0.833, 'Romance': 0.857}
#
# [Batch 2 - Sample 36]
# Input Text:    Abandoned in the barren wasteland of Kyoto, a savage, enraged orphan does whatev...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Animation', 'Drama']
# High Probs:    {'Action': 0.702, 'Adventure': 0.363, 'Animation': 0.11, 'Drama': 0.247, 'Fantasy': 0.146, 'Horror': 0.318}
#
# [Batch 2 - Sample 37]
# Input Text:    Shirley Jones plays an innocent young American abroad (Italy, specifically), ass...
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Mystery', 'Romance']
# High Probs:    {'Comedy': 0.695, 'Drama': 0.534, 'Romance': 0.954}
#
# [Batch 2 - Sample 38]
# Input Text:    A tenor sparks new hope into the life of a wife,a former piano player whose husb...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.255, 'Drama': 0.744, 'Music': 0.151, 'Musical': 0.148, 'Romance': 0.995}
#
# [Batch 2 - Sample 39]
# Input Text:    Knock Knock. Who's There? is an anthology of horror tales where ghosts and karma...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Drama', 'Horror']
# High Probs:    {'Comedy': 0.11, 'Horror': 0.996, 'Mystery': 0.156, 'Thriller': 0.148}
#
# [Batch 2 - Sample 40]
# Input Text:    Helene Wilfur is a brilliant student at a medical school devoted to research, an...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.119, 'Drama': 0.729, 'Horror': 0.114, 'Romance': 0.951}
#
# [Batch 2 - Sample 41]
# Input Text:    A noir love story between a Serbian girl and a mysterious young Albanian, set ag...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Crime', 'Drama', 'Romance']
# High Probs:    {'Comedy': 0.161, 'Drama': 0.756, 'Romance': 0.984}
#
# [Batch 2 - Sample 42]
# Input Text:    Evan, an Ex-Navy Seal is out to uncover a conspiracy after an attack on a concer...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama', 'Thriller']
# ...
#
# [Batch 4 - Sample 8]
# Input Text:    A school girl is drawn into a cult via a strange new friend on the Internet....
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.186, 'Horror': 0.942, 'Mystery': 0.222, 'Sci-Fi': 0.143, 'Thriller': 0.328}
#
# [Batch 4 - Sample 9]
# Input Text:    Siblings fleeing their abusive father, a cop, are caught in a game of supernatur...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Drama': 0.175, 'Horror': 0.992, 'Mystery': 0.202, 'Thriller': 0.445}
#
# [Batch 4 - Sample 10]
# Input Text:    Two best friends, Khang and Hieu, are sent from Ho Chi Minh City to study abroad...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Comedy': 0.423, 'Drama': 0.591, 'Romance': 0.971}
#
# [Batch 4 - Sample 11]
# Input Text:    A man tries to become a better son after his intended bride rejects him and he l...
# PREDICTED:     ['Comedy', 'Drama', 'Romance']
# GROUND TRUTH:  ['Action', 'Comedy', 'Drama']
# High Probs:    {'Comedy': 0.591, 'Drama': 0.666, 'Family': 0.148, 'Romance': 0.945}
#
# [Batch 4 - Sample 12]
# Input Text:    CIA guy and IRA guy reluctantly team up to catch IRA guy's rogue brother....
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Thriller']
# High Probs:    {'Action': 0.992, 'Adventure': 0.179, 'Comedy': 0.301, 'Crime': 0.252, 'Drama': 0.118, 'Thriller': 0.178}
#
# [Batch 4 - Sample 13]
# Input Text:    The story revolves around a film director looking for a new film face to star in...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Comedy': 0.696, 'Drama': 0.356, 'Romance': 0.969}
#
# [Batch 4 - Sample 14]
# Input Text:    ESCAPE is a spy thriller about a woman executive who is abducted in a case of mi...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.975, 'Crime': 0.167, 'Drama': 0.172, 'Thriller': 0.409}
#
# [Batch 4 - Sample 15]
# Input Text:    A group of teenagers visit an abandoned mental hospital to summon old spirits bu...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Thriller']
# High Probs:    {'Horror': 0.997, 'Thriller': 0.116}
#
# [Batch 4 - Sample 16]
# Input Text:    This movie is a Chinese romantic comedy.Its about a young couple who have been d...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Romance']
# High Probs:    {'Comedy': 0.84, 'Drama': 0.17, 'Romance': 0.994}
#
# [Batch 4 - Sample 17]
# Input Text:    In the wake of Israel's 2006 bombardment of Lebanon, a determined woman finds he...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Drama', 'Romance', 'War']
# High Probs:    {'Action': 0.753, 'Adventure': 0.315, 'Drama': 0.553, 'Romance': 0.116, 'Thriller': 0.304}
#
# [Batch 4 - Sample 18]
# Input Text:    Yakuza in Hiroshima fight to dominate corporate extortion rackets....
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Crime', 'Drama']
# High Probs:    {'Action': 0.997, 'Crime': 0.377, 'Drama': 0.253, 'Thriller': 0.124}
#
# [Batch 4 - Sample 19]
# Input Text:    A rich man returns to his first wife on finding that his second wife loves a you...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Musical', 'Romance']
# High Probs:    {'Comedy': 0.296, 'Drama': 0.647, 'Romance': 0.983}
#
# [Batch 4 - Sample 20]
# Input Text:    Penny Palabras is being tormented by a malevolent entity called the Straw Man. S...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Fantasy', 'Horror']
# High Probs:    {'Comedy': 0.246, 'Drama': 0.229, 'Horror': 0.905, 'Thriller': 0.192}
#
# [Batch 4 - Sample 21]
# Input Text:    Two cult members take a road trip in a motorhome before their predicted end of t...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Comedy', 'Horror']
# High Probs:    {'Comedy': 0.447, 'Fantasy': 0.169, 'Horror': 0.923}
#
# [Batch 4 - Sample 22]
# Input Text:    Pancho Treviño and his family is hunting in the mountains when a gang of bandits...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama']
# High Probs:    {'Action': 0.933, 'Adventure': 0.339, 'Comedy': 0.105, 'Crime': 0.105, 'Drama': 0.35, 'Western': 0.207}
#
# [Batch 4 - Sample 23]
# Input Text:    German version of the Italian film Ma Non E Una Cosa Seria, from a Pirandello st...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Romance']
# High Probs:    {'Comedy': 0.337, 'Drama': 0.727, 'Romance': 0.993}
#
# [Batch 4 - Sample 24]
# Input Text:    A team of seven young sevens football players gets involved in crime as a means ...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Crime', 'Drama']
# High Probs:    {'Action': 0.937, 'Comedy': 0.153, 'Crime': 0.395, 'Drama': 0.524, 'Thriller': 0.127}
#
# [Batch 4 - Sample 25]
# Input Text:    An openly gay star on the standup comedy circuit gets a shot at her own TV sitco...
# PREDICTED:     ['Comedy', 'Romance']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Comedy': 0.883, 'Drama': 0.249, 'Horror': 0.204, 'Romance': 0.762}
#
# [Batch 4 - Sample 26]
# Input Text:    Kim Myeong-min (39) is Agent Kim, a family man who lives contentedly with his wi...
# PREDICTED:     ['Romance']
# GROUND TRUTH:  ['Action', 'Comedy']
# High Probs:    {'Action': 0.339, 'Comedy': 0.428, 'Crime': 0.189, 'Drama': 0.458, 'Romance': 0.694}
#
# [Batch 4 - Sample 27]
# Input Text:    A graduate student preparing his thesis on mythology leads his friends on a rese...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Thriller']
# High Probs:    {'Horror': 0.997, 'Mystery': 0.207, 'Thriller': 0.142}
#
# [Batch 4 - Sample 28]
# Input Text:    Are mysterious killings in Paris of 1896 the work of man or monster?...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Fantasy', 'Horror', 'Mystery']
# High Probs:    {'Drama': 0.19, 'Horror': 0.873, 'Mystery': 0.242, 'Thriller': 0.235}
#
# [Batch 4 - Sample 29]
# Input Text:    After receiving a mysterious invite to an art exhibition, a trio of friends are ...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Fantasy', 'Horror', 'Thriller']
# High Probs:    {'Drama': 0.101, 'Horror': 0.998, 'Mystery': 0.221, 'Thriller': 0.252}
#
# [Batch 4 - Sample 30]
# Input Text:    In this horror, a slasher fiction author's stories begin manifesting in real lif...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Horror': 0.998, 'Thriller': 0.217}
#
# [Batch 4 - Sample 31]
# Input Text:    During World War II, German ships are "safely" docked upriver at Bordeaux, but t...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Drama', 'War']
# High Probs:    {'Action': 0.735, 'Adventure': 0.238, 'Drama': 0.687, 'History': 0.18, 'Romance': 0.325, 'War': 0.403}
#
# [Batch 4 - Sample 32]
# Input Text:    Feature film based on the short film written and directed by Rich Ragsdale....
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Action': 0.593, 'Comedy': 0.195, 'Drama': 0.21, 'Horror': 0.209, 'Romance': 0.177, 'Thriller': 0.103}
#
# [Batch 4 - Sample 33]
# Input Text:    Uncle and nephew try to recover their lands from a corrupt casino owner. A farme...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action', 'Comedy']
# High Probs:    {'Action': 0.803, 'Comedy': 0.187, 'Crime': 0.269, 'Drama': 0.665, 'Romance': 0.298}
#
# [Batch 4 - Sample 34]
# Input Text:    The maniacal Harley Quinn emerges ten years after the Joker's capture at the end...
# PREDICTED:     ['Action', 'Adventure']
# GROUND TRUTH:  ['Action', 'Crime', 'Drama']
# High Probs:    {'Action': 0.99, 'Adventure': 0.574, 'Animation': 0.166, 'Comedy': 0.116, 'Drama': 0.135, 'Fantasy': 0.301}
#
# [Batch 4 - Sample 35]
# Input Text:    Not available at this time....
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.617, 'Adventure': 0.107, 'Comedy': 0.144, 'Drama': 0.132, 'Fantasy': 0.108, 'Horror': 0.363, 'Romance': 0.1}
#
# [Batch 4 - Sample 36]
# Input Text:    A Shaolin Monk comes to the United States to take care of his deceased brother's...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Adventure', 'Comedy']
# High Probs:    {'Action': 0.986, 'Comedy': 0.168, 'Crime': 0.467, 'Drama': 0.474, 'Thriller': 0.126}
#
# [Batch 4 - Sample 37]
# Input Text:    The year is 2026 - Europe has been devastated by a virus that has turned a huge ...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.2, 'Comedy': 0.237, 'Drama': 0.13, 'Horror': 0.727, 'Sci-Fi': 0.161}
#
# [Batch 4 - Sample 38]
# Input Text:    In a twisted attempt to rid the world of sin, a serial killer masquerades as a p...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Drama', 'Horror', 'Mystery']
# High Probs:    {'Crime': 0.163, 'Drama': 0.137, 'Horror': 0.937, 'Mystery': 0.172, 'Thriller': 0.441}
#
# [Batch 4 - Sample 39]
# Input Text:    Raju, the only heir of a millionaire, is brainwashed by his stepmother for her g...
# PREDICTED:     ['Drama']
# GROUND TRUTH:  ['Drama', 'Romance']
# High Probs:    {'Action': 0.142, 'Comedy': 0.191, 'Crime': 0.141, 'Drama': 0.561, 'Horror': 0.407, 'Romance': 0.448, 'Thriller': 0.246}
#
# [Batch 4 - Sample 40]
# Input Text:    Agra-based atheist and revolutionary poet/editor of Inquilab, Ejaz, falls head-o...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Drama', 'Musical', 'Romance']
# High Probs:    {'Drama': 0.773, 'Musical': 0.105, 'Romance': 0.961}
#
# [Batch 4 - Sample 41]
# Input Text:    An armored car with two million dollars worth of banknotes on board is hijacked ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.998, 'Comedy': 0.126, 'Crime': 0.354, 'Drama': 0.194, 'Thriller': 0.231}
#
# [Batch 4 - Sample 42]
# Input Text:    Supernatural comedy about an unlucky high school student who dies in a bus crash...
# PREDICTED:     ['Comedy', 'Horror']
# GROUND TRUTH:  ['Comedy', 'Fantasy', 'Horror']
# High Probs:    {'Action': 0.113, 'Comedy': 0.641, 'Drama': 0.132, 'Fantasy': 0.289, 'Horror': 0.721}
#
# [Batch 4 - Sample 43]
# Input Text:    An electric surge causes a serial killer's soul to end up in a computer system....
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Sci-Fi', 'Thriller']
# High Probs:    {'Comedy': 0.138, 'Drama': 0.107, 'Horror': 0.959, 'Mystery': 0.103, 'Sci-Fi': 0.182, 'Thriller': 0.257}
#
# [Batch 4 - Sample 44]
# Input Text:    A serial killer with a split personality gets involved with a mysterious masked ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Thriller']
# High Probs:    {'Action': 0.797, 'Crime': 0.112, 'Drama': 0.125, 'Horror': 0.314, 'Sci-Fi': 0.122, 'Thriller': 0.301}
#
# [Batch 4 - Sample 45]
# Input Text:    After the collapse of the U.S. government and economy, our lone hero, Kade, find...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Adventure', 'Sci-Fi']
# High Probs:    {'Action': 0.925, 'Adventure': 0.273, 'Crime': 0.122, 'Drama': 0.33, 'Thriller': 0.108}
#
# [Batch 4 - Sample 46]
# Input Text:    Fifteen year old Parvathi manages to escape after witnessing her family getting ...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Comedy', 'Drama', 'Romance']
# High Probs:    {'Action': 0.192, 'Comedy': 0.147, 'Drama': 0.64, 'Horror': 0.111, 'Romance': 0.591}
#
# [Batch 4 - Sample 47]
# Input Text:    A defecting Soviet scientist is hit by a nuclear explosion near Yucca Flats and ...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror', 'Sci-Fi']
# High Probs:    {'Action': 0.101, 'Comedy': 0.125, 'Drama': 0.197, 'Horror': 0.829, 'Mystery': 0.159, 'Sci-Fi': 0.48, 'Thriller': 0.147}
#
# [Batch 4 - Sample 48]
# Input Text:    Psychiatrist Rosenberg encourages his weakest patients to commit strange acts....
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.229, 'Crime': 0.107, 'Drama': 0.48, 'Horror': 0.86, 'Mystery': 0.134, 'Thriller': 0.195}
#
# [Batch 4 - Sample 49]
# Input Text:    Nayana was cheated by her prospective fiancee, but when he does the same to a de...
# PREDICTED:     ['Romance']
# GROUND TRUTH:  ['Drama', 'Romance', 'Thriller']
# High Probs:    {'Comedy': 0.39, 'Drama': 0.434, 'Romance': 0.961}
#
# [Batch 4 - Sample 50]
# Input Text:    Sometimes when you turn over a new leaf all you find is dirt. This is a story th...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.707, 'Crime': 0.17, 'Drama': 0.604, 'Romance': 0.3}
#
# [Batch 4 - Sample 51]
# Input Text:    Charley, his wife Rosina and their daughter Darla attend "Bank night" at their l...
# PREDICTED:     []
# GROUND TRUTH:  ['Comedy', 'Music', 'Romance']
# High Probs:    {'Action': 0.108, 'Comedy': 0.428, 'Drama': 0.304, 'Horror': 0.481, 'Romance': 0.381}
#
# [Batch 4 - Sample 52]
# Input Text:    A deranged 15th Century prison colony chaplain exploits his power to get money f...
# PREDICTED:     ['Horror']
# GROUND TRUTH:  ['Horror']
# High Probs:    {'Comedy': 0.118, 'Crime': 0.12, 'Drama': 0.237, 'Horror': 0.906, 'Mystery': 0.112, 'Thriller': 0.123}
#
# [Batch 4 - Sample 53]
# Input Text:    Two estranged brothers - thrown together for a treasure hunt - soon find that th...
# PREDICTED:     ['Action', 'Adventure']
# GROUND TRUTH:  ['Action', 'Adventure', 'Thriller']
# High Probs:    {'Action': 0.733, 'Adventure': 0.569, 'Drama': 0.202, 'Horror': 0.23, 'Thriller': 0.158}
#
# [Batch 4 - Sample 54]
# Input Text:    Patronized by a gang ruling the city, Mako delinquently plays around a night clu...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Action', 'Crime']
# High Probs:    {'Action': 0.399, 'Comedy': 0.133, 'Crime': 0.303, 'Drama': 0.51, 'Romance': 0.507}
#
# [Batch 4 - Sample 55]
# Input Text:    THE VISION FOR A BETTER SOCIETY OUTLIVES THE MAN WHO PASSIONATELY FOUGHT FOR IT ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.974, 'Biography': 0.118, 'Drama': 0.42}
#
# [Batch 4 - Sample 56]
# Input Text:    Reeling from his previous mission loss, contractor Jedidiah "Jed" Butcher signs ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.943, 'Adventure': 0.167, 'Drama': 0.171, 'Thriller': 0.28}
#
# [Batch 4 - Sample 57]
# Input Text:    A woman scorned, kidnapped at a young age to work in a brothel, sold by her pare...
# PREDICTED:     ['Action', 'Drama']
# GROUND TRUTH:  ['Romance', 'Thriller']
# High Probs:    {'Action': 0.582, 'Crime': 0.357, 'Drama': 0.658, 'Romance': 0.226, 'Thriller': 0.273}
#
# [Batch 4 - Sample 58]
# Input Text:    A deadly virus attacks the crew of a Saturn space station....
# PREDICTED:     ['Horror', 'Sci-Fi']
# GROUND TRUTH:  ['Horror', 'Sci-Fi']
# High Probs:    {'Action': 0.416, 'Adventure': 0.164, 'Drama': 0.276, 'Horror': 0.546, 'Sci-Fi': 0.582, 'Thriller': 0.196}
#
# [Batch 4 - Sample 59]
# Input Text:    An underworld kingpin recruits people endowed with 'Luck' from across the globe ...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Adventure', 'Drama']
# High Probs:    {'Action': 0.951, 'Adventure': 0.345, 'Comedy': 0.202, 'Crime': 0.357, 'Drama': 0.194, 'Thriller': 0.135}
#
# [Batch 4 - Sample 60]
# Input Text:    Sara and Alex lost the son they were expecting due to miscarriage and since that...
# PREDICTED:     ['Drama', 'Romance']
# GROUND TRUTH:  ['Horror', 'Thriller']
# High Probs:    {'Comedy': 0.422, 'Drama': 0.542, 'Horror': 0.112, 'Romance': 0.881}
#
# [Batch 4 - Sample 61]
# Input Text:    A group of renegade mercenaries get back together, to get revenge on the man who...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.971, 'Comedy': 0.113, 'Drama': 0.25, 'Thriller': 0.124}
#
# [Batch 4 - Sample 62]
# Input Text:    Jamie Stratton's quirky new wife infiltrates MKU to plant Jamie, his twin brothe...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action']
# High Probs:    {'Action': 0.99, 'Adventure': 0.421, 'Comedy': 0.489}
#
# [Batch 4 - Sample 63]
# Input Text:    Vijay Kumar, a forest officer returns to the forest where his dad met an untimel...
# PREDICTED:     ['Action']
# GROUND TRUTH:  ['Action', 'Drama']
# High Probs:    {'Action': 0.987, 'Adventure': 0.128, 'Crime': 0.103, 'Drama': 0.326, 'Thriller': 0.214}
#
# ==============================
# FINAL EVALUATION REPORT
# ==============================
# Global Accuracy: 0.9467
# Global F1: 0.6235
# Global Precision: 0.7587
# Global Recall: 0.5292
